# %%
from api_key import client_secret
from api_key import client_id
from api_key import api_key
from suburb_list import suburb_list_melbourne
from suburb_list import values
import requests
import json
import gmaps
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
import csv

# %%
scopes = ['api_addresslocators_read']
auth_url = 'https://auth.domain.com.au/v1/connect/token'
url_endpoint = 'https://api.domain.com.au/sandbox/v1/addressLocators/'
suburb_id = []
postcode_list = []
response = requests.post(auth_url, data = {'client_id':client_id,
                                               'client_secret':client_secret,
                                               'grant_type':'client_credentials',
                                               'scope':scopes,
                                               'Content-Type':'text/json'
                                              })
json_res = response.json()
access_token=json_res['access_token']
for suburb in suburb_list_melbourne:
    params = {"searchLevel" : "Suburb",
             "suburb" : suburb,
             "state" : "vic"}
    #print(access_token)
    auth = {'Authorization':'Bearer ' + access_token}
    res1 = requests.get(url_endpoint, headers=auth , params = params)    
    try:
        r = res1.json()
        print(f"there is correct suburb id in {suburb}")
        suburb_id.append(r[0]["ids"][0]['id'])
        postcode_list.append(r[0]["addressComponents"][1]['shortName'])
    except:
        print(f"there is no suburb id in {suburb}")
        suburb_id.append("N/A")
        postcode_list.append("N/A")
# Out:
# there is correct suburb id in Abbotsford
# there is correct suburb id in Aberfeldie
# there is correct suburb id in Airport West
# there is correct suburb id in Albanvale
# there is correct suburb id in Albert Park
# there is correct suburb id in Albion
# there is correct suburb id in Alphington
# there is correct suburb id in Altona Meadows
# there is correct suburb id in Altona North
# there is correct suburb id in Altona
# there is correct suburb id in Ardeer
# there is correct suburb id in Armadale
# there is correct suburb id in Arthurs Seat
# there is correct suburb id in Ascot Vale
# there is correct suburb id in Ashburton
# there is correct suburb id in Ashwood
# there is correct suburb id in Aspendale
# there is correct suburb id in Aspendale Gardens
# there is correct suburb id in Attwood
# there is correct suburb id in Auburn
# there is no suburb id in Auburn
# there is correct suburb id in Aurora
# there is no suburb id in Aurora
# there is correct suburb id in Avondale Heights
# there is correct suburb id in Avonsleigh
# there is correct suburb id in Balaclava
# there is correct suburb id in Balwyn
# there is correct suburb id in Balwyn North
# there is correct suburb id in Bangholme
# there is correct suburb id in Baxter
# there is correct suburb id in Bayswater
# there is correct suburb id in Bayswater North
# there is correct suburb id in Beaconsfield
# there is correct suburb id in Beaumaris
# there is correct suburb id in Belgrave
# there is correct suburb id in Belgrave Heights
# there is correct suburb id in Belgrave South
# there is correct suburb id in Bellfield
# there is correct suburb id in Bennettswood
# there is no suburb id in Bennettswood
# there is correct suburb id in Bentleigh
# there is correct suburb id in Bentleigh East
# there is correct suburb id in Berwick
# there is correct suburb id in Bittern
# there is correct suburb id in Black Rock
# there is correct suburb id in Blackburn
# there is correct suburb id in Blackburn North
# there is correct suburb id in Blackburn South
# there is correct suburb id in Blairgowrie
# there is correct suburb id in Bonbeach
# there is correct suburb id in Boronia
# there is correct suburb id in Box Hill
# there is correct suburb id in Box Hill North
# there is correct suburb id in Box Hill South
# there is correct suburb id in Braeside
# there is correct suburb id in Braybrook
# there is correct suburb id in Briar Hill
# there is correct suburb id in Brighton
# there is correct suburb id in Brighton East
# there is correct suburb id in Broadmeadows
# there is correct suburb id in Brookfield
# there is correct suburb id in Brooklyn
# there is correct suburb id in Brunswick
# there is correct suburb id in Brunswick East
# there is correct suburb id in Brunswick West
# there is correct suburb id in Bulla
# there is correct suburb id in Bulleen
# there is correct suburb id in Bundoora
# there is correct suburb id in Burnley
# there is correct suburb id in Burnside
# there is correct suburb id in Burnside Heights
# there is correct suburb id in Burwood
# there is correct suburb id in Burwood East
# there is correct suburb id in Cairnlea
# there is correct suburb id in Calder Park
# there is correct suburb id in Camberwell
# there is correct suburb id in Campbellfield
# there is correct suburb id in Canterbury
# there is correct suburb id in Carlton North
# there is correct suburb id in Carlton
# there is correct suburb id in Carnegie
# there is correct suburb id in Caroline Springs
# there is correct suburb id in Carrum
# there is correct suburb id in Carrum Downs
# there is correct suburb id in Caulfield
# there is correct suburb id in Caulfield East
# there is correct suburb id in Caulfield North
# there is correct suburb id in Caulfield South
# there is correct suburb id in Chadstone
# there is correct suburb id in Chelsea
# there is correct suburb id in Chelsea Heights
# there is correct suburb id in Cheltenham
# there is correct suburb id in Chirnside Park
# there is correct suburb id in Clarinda
# there is correct suburb id in Clayton
# there is correct suburb id in Clayton South
# there is correct suburb id in Clematis
# there is correct suburb id in Clifton Hill
# there is correct suburb id in Coburg
# there is correct suburb id in Coburg North
# there is correct suburb id in Cocoroc
# there is correct suburb id in Coldstream
# there is correct suburb id in Collingwood
# there is correct suburb id in Coolaroo
# there is correct suburb id in Craigieburn
# there is correct suburb id in Cranbourne
# there is correct suburb id in Cranbourne East
# there is correct suburb id in Cranbourne North
# there is correct suburb id in Cranbourne South
# there is correct suburb id in Cranbourne West
# there is correct suburb id in Cremorne
# there is correct suburb id in Crib Point
# there is correct suburb id in Croydon
# there is correct suburb id in Croydon Hills
# there is correct suburb id in Croydon North
# there is correct suburb id in Croydon South
# there is correct suburb id in Dallas
# there is correct suburb id in Dandenong
# there is correct suburb id in Dandenong North
# there is correct suburb id in Dandenong South
# there is correct suburb id in Deer Park
# there is correct suburb id in Delahey
# there is correct suburb id in Derrimut
# there is correct suburb id in Diamond Creek
# there is correct suburb id in Dingley Village
# there is correct suburb id in Docklands
# there is correct suburb id in Doncaster
# there is correct suburb id in Doncaster East
# there is correct suburb id in Donvale
# there is correct suburb id in Doreen
# there is correct suburb id in Doveton
# there is correct suburb id in Dromana
# there is correct suburb id in Eaglemont
# there is correct suburb id in East Melbourne
# there is correct suburb id in Edithvale
# there is correct suburb id in Elsternwick
# there is correct suburb id in Eltham
# there is correct suburb id in Eltham North
# there is correct suburb id in Elwood
# there is correct suburb id in Emerald
# there is correct suburb id in Endeavour Hills
# there is correct suburb id in Epping
# there is correct suburb id in Essendon Fields
# there is correct suburb id in Essendon North
# there is correct suburb id in Essendon West
# there is correct suburb id in Essendon
# there is correct suburb id in Eumemmerring
# there is correct suburb id in Fairfield
# there is correct suburb id in Fawkner
# there is correct suburb id in Ferntree Gully
# there is correct suburb id in Ferny Creek
# there is correct suburb id in Fitzroy
# there is correct suburb id in Fitzroy North
# there is correct suburb id in Flemington
# there is correct suburb id in Footscray
# there is correct suburb id in Forest Hill
# there is correct suburb id in Frankston
# there is correct suburb id in Frankston North
# there is correct suburb id in Frankston South
# there is correct suburb id in Gardenvale
# there is correct suburb id in Gladstone Park
# there is correct suburb id in Glen Huntly
# there is correct suburb id in Glen Iris
# there is correct suburb id in Glen Waverley
# there is correct suburb id in Glenroy
# there is correct suburb id in Gowanbrae
# there is correct suburb id in Greensborough
# there is correct suburb id in Greenvale Lakes
# there is no suburb id in Greenvale Lakes
# there is correct suburb id in Greenvale
# there is correct suburb id in Guys Hill
# there is correct suburb id in Hadfield
# there is correct suburb id in Hallam
# there is correct suburb id in Hampton
# there is correct suburb id in Hampton East
# there is correct suburb id in Hampton Park
# there is correct suburb id in Harkaway
# there is correct suburb id in Hawthorn
# there is correct suburb id in Hawthorn East
# there is correct suburb id in Heatherdale
# there is no suburb id in Heatherdale
# there is correct suburb id in Heatherton
# there is correct suburb id in Heathmont
# there is correct suburb id in Heidelberg
# there is correct suburb id in Heidelberg Heights
# there is correct suburb id in Heidelberg West
# there is correct suburb id in Highett
# there is correct suburb id in Hillside
# there is correct suburb id in Hoppers Crossing
# there is correct suburb id in Houston
# there is no suburb id in Houston
# there is correct suburb id in Hughesdale
# there is correct suburb id in Huntingdale
# there is correct suburb id in Hurstbridge
# there is correct suburb id in Ivanhoe
# there is correct suburb id in Ivanhoe East
# there is correct suburb id in Jacana
# there is correct suburb id in Junction Village
# there is correct suburb id in Kallista
# there is correct suburb id in Kalorama
# there is correct suburb id in Karingal
# there is no suburb id in Karingal
# there is correct suburb id in Kealba
# there is correct suburb id in Keilor
# there is correct suburb id in Keilor Downs
# there is correct suburb id in Keilor East
# there is correct suburb id in Keilor Lodge
# there is correct suburb id in Keilor North
# there is correct suburb id in Keilor Park
# there is correct suburb id in Kensington
# there is correct suburb id in Kerrimuir
# there is no suburb id in Kerrimuir
# there is correct suburb id in Kew
# there is correct suburb id in Kew East
# there is correct suburb id in Keysborough
# there is correct suburb id in Kilsyth
# there is correct suburb id in Kilsyth South
# there is correct suburb id in Kings Park
# there is correct suburb id in Kingsbury
# there is correct suburb id in Kingsville
# there is correct suburb id in Knoxfield
# there is correct suburb id in Kooyong
# there is correct suburb id in Kurunjang
# there is correct suburb id in Laburnum
# there is no suburb id in Laburnum
# there is correct suburb id in Lalor
# there is correct suburb id in Langwarrin
# there is correct suburb id in Langwarrin South
# there is correct suburb id in Laverton
# there is correct suburb id in Laverton North
# there is correct suburb id in Lilydale
# there is correct suburb id in Lower Plenty
# there is correct suburb id in Lynbrook
# there is correct suburb id in Lyndhurst
# there is correct suburb id in Lysterfield
# there is correct suburb id in Lysterfield South
# there is correct suburb id in Macclesfield
# there is correct suburb id in McCrae
# there is correct suburb id in McKinnon
# there is correct suburb id in Macleod
# there is correct suburb id in Maidstone
# there is correct suburb id in Malvern
# there is correct suburb id in Malvern East
# there is correct suburb id in Maribyrnong
# there is correct suburb id in Meadow Heights
# there is correct suburb id in Melbourne Airport
# there is correct suburb id in Melton (suburb)
# there is no suburb id in Melton (suburb)
# there is correct suburb id in Melton South
# there is correct suburb id in Melton West
# there is correct suburb id in Mentone
# there is correct suburb id in Menzies Creek
# there is correct suburb id in Mernda
# there is correct suburb id in Mickleham
# there is correct suburb id in Middle Park
# there is correct suburb id in Milgate Park Estate
# there is no suburb id in Milgate Park Estate
# there is correct suburb id in Mill Park
# there is correct suburb id in Mitcham
# there is correct suburb id in Monbulk
# there is correct suburb id in Mont Albert
# there is correct suburb id in Mont Albert North
# there is correct suburb id in Montmorency
# there is correct suburb id in Montrose
# there is correct suburb id in Moonee Ponds
# there is correct suburb id in Moorabbin Airport
# there is correct suburb id in Moorabbin
# there is correct suburb id in Moorooduc
# there is correct suburb id in Mooroolbark
# there is correct suburb id in Mordialloc
# there is correct suburb id in Mornington
# there is correct suburb id in Mount Dandenong
# there is correct suburb id in Mount Eliza
# there is correct suburb id in Mount Evelyn
# there is correct suburb id in Mount Martha
# there is correct suburb id in Mount Waverley
# there is correct suburb id in Mulgrave
# there is correct suburb id in Narre Warren East
# there is correct suburb id in Narre Warren North
# there is correct suburb id in Narre Warren South
# there is correct suburb id in Narre Warren
# there is correct suburb id in Newport
# there is correct suburb id in Niddrie
# there is correct suburb id in Noble Park
# there is correct suburb id in Noble Park North
# there is correct suburb id in North Melbourne
# there is correct suburb id in North Richmond
# there is no suburb id in North Richmond
# there is correct suburb id in North Warrandyte
# there is correct suburb id in Northcote
# there is correct suburb id in Norwood
# there is no suburb id in Norwood
# there is correct suburb id in Notting Hill
# there is correct suburb id in Nunawading
# there is correct suburb id in Oak Park
# there is correct suburb id in Oaklands Junction
# there is correct suburb id in Oakleigh
# there is correct suburb id in Oakleigh East
# there is correct suburb id in Oakleigh South
# there is correct suburb id in Olinda
# there is correct suburb id in Olivers Hill
# there is no suburb id in Olivers Hill
# there is correct suburb id in Ormond
# there is correct suburb id in Pakenham
# there is correct suburb id in Panton Hill
# there is correct suburb id in Park Orchards
# there is correct suburb id in Parkdale
# there is correct suburb id in Parkville
# there is correct suburb id in Pascoe Vale South
# there is correct suburb id in Pascoe Vale
# there is correct suburb id in The Patch
# there is correct suburb id in Patterson Lakes
# there is correct suburb id in Pennydale
# there is no suburb id in Pennydale
# there is correct suburb id in Plenty
# there is correct suburb id in Point Cook
# there is correct suburb id in Port Melbourne
# there is correct suburb id in Portsea
# there is correct suburb id in Prahran
# there is correct suburb id in Preston
# there is correct suburb id in Princes Hill
# there is correct suburb id in Ravenhall
# there is correct suburb id in Research
# there is correct suburb id in Reservoir
# there is correct suburb id in Richmond
# there is correct suburb id in Ringwood
# there is correct suburb id in Ringwood East
# there is correct suburb id in Ringwood North
# there is correct suburb id in Ripponlea
# there is correct suburb id in Rockbank
# there is correct suburb id in Rosanna
# there is correct suburb id in Rosebud
# there is correct suburb id in Rosebud West
# there is no suburb id in Rosebud West
# there is correct suburb id in Rowville
# there is correct suburb id in Roxburgh Park
# there is correct suburb id in Rye
# there is correct suburb id in Safety Beach
# there is correct suburb id in St Albans
# there is correct suburb id in St Helena
# there is correct suburb id in St Kilda
# there is correct suburb id in St Kilda East
# there is correct suburb id in St Kilda West
# there is correct suburb id in Sandhurst
# there is correct suburb id in Sandringham
# there is correct suburb id in Sassafras
# there is correct suburb id in Scoresby
# there is correct suburb id in Seabrook
# there is correct suburb id in Seaford
# there is correct suburb id in Seaholme
# there is correct suburb id in Seddon
# there is correct suburb id in Selby
# there is correct suburb id in Seville
# there is correct suburb id in Sherbrooke
# there is correct suburb id in Skye
# there is correct suburb id in Somerton
# there is correct suburb id in Sorrento
# there is correct suburb id in South Kingsville
# there is correct suburb id in South Melbourne
# there is correct suburb id in South Morang
# there is correct suburb id in South Wharf
# there is correct suburb id in South Yarra
# there is correct suburb id in Southbank
# there is correct suburb id in Spotswood
# there is correct suburb id in Springvale
# there is correct suburb id in Springvale South
# there is correct suburb id in Strathmore
# there is correct suburb id in Strathmore Heights
# there is correct suburb id in Sunbury
# there is correct suburb id in Sunshine
# there is correct suburb id in Sunshine North
# there is correct suburb id in Sunshine West
# there is correct suburb id in Surrey Hills
# there is correct suburb id in Sydenham
# there is correct suburb id in Syndal
# there is no suburb id in Syndal
# there is correct suburb id in Tally Ho
# there is no suburb id in Tally Ho
# there is correct suburb id in Tarneit
# there is correct suburb id in Taylors Hill
# there is correct suburb id in Taylors Lakes
# there is correct suburb id in Tecoma
# there is correct suburb id in Templestowe
# there is correct suburb id in Templestowe Lower
# there is correct suburb id in The Basin
# there is correct suburb id in Thomastown
# there is correct suburb id in Thornbury
# there is correct suburb id in Toorak
# there is correct suburb id in Tootgarook
# there is correct suburb id in Tottenham
# there is correct suburb id in Travancore
# there is correct suburb id in Tremont
# there is correct suburb id in Truganina
# there is correct suburb id in Tullamarine
# there is correct suburb id in Upfield
# there is no suburb id in Upfield
# there is correct suburb id in Upper Ferntree Gully
# there is correct suburb id in Upwey
# there is correct suburb id in Vermont
# there is correct suburb id in Vermont South
# there is correct suburb id in Viewbank
# there is correct suburb id in Wantirna
# there is correct suburb id in Wantirna South
# there is correct suburb id in Warrandyte
# there is correct suburb id in Warrandyte South
# there is correct suburb id in Warranwood
# there is correct suburb id in Waterways
# there is correct suburb id in Watsonia
# there is correct suburb id in Watsonia North
# there is correct suburb id in Wattle Glen
# there is correct suburb id in Waverley Park
# there is no suburb id in Waverley Park
# there is correct suburb id in Werribee
# there is correct suburb id in Werribee South
# there is correct suburb id in West Footscray
# there is correct suburb id in West Melbourne
# there is correct suburb id in Westgarth
# there is no suburb id in Westgarth
# there is correct suburb id in Westmeadows
# there is correct suburb id in Wheelers Hill
# there is correct suburb id in Wildwood
# there is correct suburb id in Williams Landing
# there is correct suburb id in Williamstown
# there is correct suburb id in Williamstown North
# there is correct suburb id in Windsor
# there is correct suburb id in Wonga Park
# there is correct suburb id in Wyndham Vale
# there is correct suburb id in Yallambie
# there is correct suburb id in Yarrambat
# there is correct suburb id in Yarraville
# there is correct suburb id in Yuroke

# %%
city_id = pd.DataFrame({"Suburb" : suburb_list_melbourne,
                        "ID_Domain" : suburb_id,
                       "Postcode" : postcode_list})
city_id.to_csv("Resources/city_id_postcode.csv")

# %%
city_id_clean = pd.read_csv("Resources/city_id_postcode.csv").dropna()
city_id_clean = city_id_clean.iloc[: , 1:]
city_id_clean['ID_Domain'] = city_id_clean['ID_Domain'].astype(int)
city_id_clean['Postcode'] = city_id_clean['Postcode'].astype(int)
city_id_clean['Postcode'] = city_id_clean['Postcode'].astype(str)
suburb_dataset = city_id_clean.set_index('Postcode')
suburb_dataset.head()
# Out:
#                 Suburb  ID_Domain
# Postcode
# 3067        Abbotsford        627
# 3040        Aberfeldie        647
# 3042      Airport West        757
# 3021         Albanvale        787
# 3206       Albert Park        797

# %%
yearly_data_2019 = suburb_dataset.copy()
yearly_data_2020 = suburb_dataset.copy()
yearly_data_2021 = suburb_dataset.copy()
yearly_data_2021.head()
# Out:
#                 Suburb  ID_Domain
# Postcode
# 3067        Abbotsford        627
# 3040        Aberfeldie        647
# 3042      Airport West        757
# 3021         Albanvale        787
# 3206       Albert Park        797

# %%
#set a dataframe with the title at the first colume
title_of_pd = ["Median Sold Price",
         "Number Sold",
         "Highest Sold Price","Lowest Sold Price",
         "5th Percentile Sold Price",
         "25th Percentile Sold Price",
         "75th Percentile Sold Price",
        "95th Percentile Sold Price",
        "Meidan Sale Listing Price",
        "Number Sale Listing",
        "Highest Sale Listing Price",
        "Lowest Sale Listing Price",
        "Auction Number Auctioned",
         "Auction Number Sold",
        "Median Rent Listing Price",
         "Number Rent Listing",
         "Highest Rend Listing Price",
         "Lowest Rend Listing Price"]
yearly_data = pd.DataFrame(columns = title_of_pd)
yearly_data["Suburb"] = city_id_clean["Suburb"]
first_column = yearly_data.pop('Suburb')
  
# insert column using insert(position,column_name,
# first_column) function
yearly_data.insert(0, 'Name', first_column)
yearly_data['Postcode'] = city_id_clean["Postcode"]
yearly_data_reset_index = yearly_data.set_index('Postcode')

yearly_data_2019 = suburb_dataset
yearly_data_2020 = suburb_dataset
yearly_data_2021 = suburb_dataset
yearly_data_2021.head()
# Out:
#                   Name Median Sold Price Number Sold Highest Sold Price  \
# Postcode
# 3067        Abbotsford               NaN         NaN                NaN
# 3040        Aberfeldie               NaN         NaN                NaN
# 3042      Airport West               NaN         NaN                NaN
# 3021         Albanvale               NaN         NaN                NaN
# 3206       Albert Park               NaN         NaN                NaN
#
#          Lowest Sold Price 5th Percentile Sold Price  \
# Postcode
# 3067                   NaN                       NaN
# 3040                   NaN                       NaN
# 3042                   NaN                       NaN
# 3021                   NaN                       NaN
# 3206                   NaN                       NaN
#
#          25th Percentile Sold Price 75th Percentile Sold Price  \
# Postcode
# 3067                            NaN                        NaN
# 3040                            NaN                        NaN
# 3042                            NaN                        NaN
# 3021                            NaN                        NaN
# 3206                            NaN                        NaN
#
#          95th Percentile Sold Price Meidan Sale Listing Price  \
# Postcode
# 3067                            NaN                       NaN
# 3040                            NaN                       NaN
# 3042                            NaN                       NaN
# 3021                            NaN                       NaN
# 3206                            NaN                       NaN
#
#          Number Sale Listing Highest Sale Listing Price  \
# Postcode
# 3067                     NaN                        NaN
# 3040                     NaN                        NaN
# 3042                     NaN                        NaN
# 3021                     NaN                        NaN
# 3206                     NaN                        NaN
#
#          Lowest Sale Listing Price Auction Number Auctioned  \
# Postcode
# 3067                           NaN                      NaN
# 3040                           NaN                      NaN
# 3042                           NaN                      NaN
# 3021                           NaN                      NaN
# 3206                           NaN                      NaN
#
#          Auction Number Sold Median Rent Listing Price Number Rent Listing  \
# Postcode
# 3067                     NaN                       NaN                 NaN
# 3040                     NaN                       NaN                 NaN
# 3042                     NaN                       NaN                 NaN
# 3021                     NaN                       NaN                 NaN
# 3206                     NaN                       NaN                 NaN
#
#          Highest Rend Listing Price Lowest Rend Listing Price
# Postcode
# 3067                            NaN                       NaN
# 3040                            NaN                       NaN
# 3042                            NaN                       NaN
# 3021                            NaN                       NaN
# 3206                            NaN                       NaN

# %%
postcode_list_clean = city_id_clean["Postcode"].tolist()
postcode_list_clean
# Out:
# ['3067',
#  '3040',
#  '3042',
#  '3021',
#  '3206',
#  '3020',
#  '3078',
#  '3028',
#  '3025',
#  '3018',
#  '3022',
#  '3143',
#  '3936',
#  '3032',
#  '3147',
#  '3147',
#  '3195',
#  '3195',
#  '3049',
#  '3034',
#  '3782',
#  '3183',
#  '3103',
#  '3104',
#  '3175',
#  '3911',
#  '3153',
#  '3153',
#  '3807',
#  '3193',
#  '3160',
#  '3160',
#  '3160',
#  '3081',
#  '3204',
#  '3165',
#  '3806',
#  '3918',
#  '3193',
#  '3130',
#  '3130',
#  '3130',
#  '3942',
#  '3196',
#  '3155',
#  '3128',
#  '3129',
#  '3128',
#  '3195',
#  '3019',
#  '3088',
#  '3186',
#  '3187',
#  '3047',
#  '3338',
#  '3012',
#  '3056',
#  '3057',
#  '3055',
#  '3428',
#  '3105',
#  '3083',
#  '3121',
#  '3023',
#  '3023',
#  '3125',
#  '3151',
#  '3023',
#  '3037',
#  '3124',
#  '3061',
#  '3126',
#  '3054',
#  '3053',
#  '3163',
#  '3023',
#  '3197',
#  '3201',
#  '3162',
#  '3145',
#  '3161',
#  '3162',
#  '3148',
#  '3196',
#  '3196',
#  '3192',
#  '3116',
#  '3169',
#  '3168',
#  '3169',
#  '3782',
#  '3068',
#  '3058',
#  '3058',
#  '3030',
#  '3770',
#  '3066',
#  '3048',
#  '3064',
#  '3977',
#  '3977',
#  '3977',
#  '3977',
#  '3977',
#  '3121',
#  '3919',
#  '3136',
#  '3136',
#  '3136',
#  '3136',
#  '3047',
#  '3175',
#  '3175',
#  '3175',
#  '3023',
#  '3037',
#  '3026',
#  '3089',
#  '3172',
#  '3008',
#  '3108',
#  '3109',
#  '3111',
#  '3754',
#  '3177',
#  '3936',
#  '3084',
#  '3002',
#  '3196',
#  '3185',
#  '3095',
#  '3095',
#  '3184',
#  '3782',
#  '3802',
#  '3076',
#  '3041',
#  '3041',
#  '3040',
#  '3040',
#  '3177',
#  '3078',
#  '3060',
#  '3156',
#  '3786',
#  '3065',
#  '3068',
#  '3031',
#  '3011',
#  '3131',
#  '3199',
#  '3200',
#  '3199',
#  '3185',
#  '3043',
#  '3163',
#  '3146',
#  '3150',
#  '3046',
#  '3043',
#  '3088',
#  '3059',
#  '3807',
#  '3046',
#  '3803',
#  '3188',
#  '3188',
#  '3976',
#  '3806',
#  '3122',
#  '3123',
#  '3202',
#  '3135',
#  '3084',
#  '3081',
#  '3081',
#  '3190',
#  '3037',
#  '3029',
#  '3166',
#  '3166',
#  '3099',
#  '3079',
#  '3079',
#  '3047',
#  '3977',
#  '3791',
#  '3766',
#  '3021',
#  '3036',
#  '3038',
#  '3033',
#  '3038',
#  '3036',
#  '3042',
#  '3031',
#  '3101',
#  '3102',
#  '3173',
#  '3137',
#  '3137',
#  '3021',
#  '3083',
#  '3012',
#  '3180',
#  '3144',
#  '3337',
#  '3075',
#  '3910',
#  '3911',
#  '3028',
#  '3026',
#  '3140',
#  '3093',
#  '3975',
#  '3975',
#  '3156',
#  '3156',
#  '3782',
#  '3938',
#  '3204',
#  '3085',
#  '3012',
#  '3144',
#  '3145',
#  '3032',
#  '3048',
#  '3045',
#  '3338',
#  '3337',
#  '3194',
#  '3159',
#  '3754',
#  '3064',
#  '3206',
#  '3082',
#  '3132',
#  '3793',
#  '3127',
#  '3129',
#  '3094',
#  '3765',
#  '3039',
#  '3194',
#  '3189',
#  '3933',
#  '3138',
#  '3195',
#  '3931',
#  '3767',
#  '3930',
#  '3796',
#  '3934',
#  '3149',
#  '3170',
#  '3804',
#  '3804',
#  '3805',
#  '3805',
#  '3015',
#  '3042',
#  '3174',
#  '3174',
#  '3051',
#  '3113',
#  '3070',
#  '3168',
#  '3131',
#  '3046',
#  '3063',
#  '3166',
#  '3166',
#  '3167',
#  '3788',
#  '3204',
#  '3810',
#  '3759',
#  '3114',
#  '3195',
#  '3052',
#  '3044',
#  '3044',
#  '3792',
#  '3197',
#  '3090',
#  '3030',
#  '3207',
#  '3944',
#  '3181',
#  '3072',
#  '3054',
#  '3023',
#  '3095',
#  '3073',
#  '3121',
#  '3134',
#  '3135',
#  '3134',
#  '3185',
#  '3335',
#  '3084',
#  '3939',
#  '3178',
#  '3064',
#  '3941',
#  '3936',
#  '3021',
#  '3088',
#  '3182',
#  '3183',
#  '3182',
#  '3977',
#  '3191',
#  '3787',
#  '3179',
#  '3028',
#  '3198',
#  '3018',
#  '3011',
#  '3159',
#  '3139',
#  '3789',
#  '3977',
#  '3062',
#  '3943',
#  '3015',
#  '3205',
#  '3752',
#  '3006',
#  '3141',
#  '3006',
#  '3015',
#  '3171',
#  '3172',
#  '3041',
#  '3041',
#  '3429',
#  '3020',
#  '3020',
#  '3020',
#  '3127',
#  '3037',
#  '3029',
#  '3037',
#  '3038',
#  '3160',
#  '3106',
#  '3107',
#  '3154',
#  '3074',
#  '3071',
#  '3142',
#  '3941',
#  '3012',
#  '3032',
#  '3785',
#  '3029',
#  '3043',
#  '3156',
#  '3158',
#  '3133',
#  '3133',
#  '3084',
#  '3152',
#  '3152',
#  '3113',
#  '3134',
#  '3134',
#  '3195',
#  '3087',
#  '3087',
#  '3096',
#  '3030',
#  '3030',
#  '3012',
#  '3003',
#  '3049',
#  '3150',
#  '3429',
#  '3027',
#  '3016',
#  '3016',
#  '3181',
#  '3115',
#  '3024',
#  '3085',
#  '3091',
#  '3013',
#  '3063']

# %%
#create a list to restore the number
scopes = ['api_suburbperformance_read']
auth_url = 'https://auth.domain.com.au/v1/connect/token'
response = requests.post(auth_url, data = {
                            'client_id':client_id,
                            'client_secret':client_secret,
                            'grant_type':'client_credentials',
                            'scope':scopes,
                            'Content-Type':'text/json'
                            })
json_res = response.json()
access_token=json_res['access_token']
auth = {'Authorization':'Bearer ' + access_token}
i = 0
for suburb in suburb_dataset['Suburb']:
    postcode_number = postcode_list_clean[i]
    print(postcode_number)
    url_sale = f'https://api.domain.com.au/sandbox/v2/suburbPerformanceStatistics/VIC/{suburb}/{postcode_number}?'
    params = {"propertyCategory" : "House",
             "periodSize" : "years",
             "startingPeriodRelativeToCurrent":1,
             "totalPeriods":3}
    res = requests.get(url_sale, headers=auth, params = params)
    try:
        s = res.json()
    #s["series"]["seriesInfo"][0]["values"] represent 2019
    #s["series"]["seriesInfo"][1]["values"] represent 2020
    #s["series"]["seriesInfo"][2]["values"] represent 2021
        for value in values:
            try:
                yearly_data_2019.loc[postcode_number,value] = s["series"]["seriesInfo"][0]["values"][value]
                yearly_data_2020.loc[postcode_number,value] = s["series"]["seriesInfo"][1]["values"][value]
                yearly_data_2021.loc[postcode_number,value] = s["series"]["seriesInfo"][2]["values"][value]
                print(f"there is data with in {suburb} of {value}")
            except JSONDecodeError:
                print(f"there is no value in {suburb} of {value}")
                yearly_data_2019.loc[postcode_number,value] = "N/A"
                yearly_data_2020.loc[postcode_number,value] = "N/A"
                yearly_data_2021.loc[postcode_number,value] = "N/A"
    i = i + 1
# Out:
# 3067
# there is data with in Abbotsford of medianSoldPrice
# there is data with in Abbotsford of numberSold
# there is data with in Abbotsford of highestSoldPrice
# there is data with in Abbotsford of lowestSoldPrice
# there is data with in Abbotsford of 5thPercentileSoldPrice
# there is data with in Abbotsford of 25thPercentileSoldPrice
# there is data with in Abbotsford of 75thPercentileSoldPrice
# there is data with in Abbotsford of 95thPercentileSoldPrice
# there is data with in Abbotsford of medianSaleListingPrice
# there is data with in Abbotsford of numberSaleListing
# there is data with in Abbotsford of highestSaleListingPrice
# there is data with in Abbotsford of lowestSaleListingPrice
# there is data with in Abbotsford of auctionNumberAuctioned
# there is data with in Abbotsford of auctionNumberSold
# there is data with in Abbotsford of medianRentListingPrice
# there is data with in Abbotsford of numberRentListing
# there is data with in Abbotsford of highestRentListingPrice
# there is data with in Abbotsford of lowestRentListingPrice
# 3040
# there is data with in Aberfeldie of medianSoldPrice
# there is data with in Aberfeldie of numberSold
# there is data with in Aberfeldie of highestSoldPrice
# there is data with in Aberfeldie of lowestSoldPrice
# there is data with in Aberfeldie of 5thPercentileSoldPrice
# there is data with in Aberfeldie of 25thPercentileSoldPrice
# there is data with in Aberfeldie of 75thPercentileSoldPrice
# there is data with in Aberfeldie of 95thPercentileSoldPrice
# there is data with in Aberfeldie of medianSaleListingPrice
# there is data with in Aberfeldie of numberSaleListing
# there is data with in Aberfeldie of highestSaleListingPrice
# there is data with in Aberfeldie of lowestSaleListingPrice
# there is data with in Aberfeldie of auctionNumberAuctioned
# there is data with in Aberfeldie of auctionNumberSold
# there is data with in Aberfeldie of medianRentListingPrice
# there is data with in Aberfeldie of numberRentListing
# there is data with in Aberfeldie of highestRentListingPrice
# there is data with in Aberfeldie of lowestRentListingPrice
# 3042
# there is data with in Airport West of medianSoldPrice
# there is data with in Airport West of numberSold
# there is data with in Airport West of highestSoldPrice
# there is data with in Airport West of lowestSoldPrice
# there is data with in Airport West of 5thPercentileSoldPrice
# there is data with in Airport West of 25thPercentileSoldPrice
# there is data with in Airport West of 75thPercentileSoldPrice
# there is data with in Airport West of 95thPercentileSoldPrice
# there is data with in Airport West of medianSaleListingPrice
# there is data with in Airport West of numberSaleListing
# there is data with in Airport West of highestSaleListingPrice
# there is data with in Airport West of lowestSaleListingPrice
# there is data with in Airport West of auctionNumberAuctioned
# there is data with in Airport West of auctionNumberSold
# there is data with in Airport West of medianRentListingPrice
# there is data with in Airport West of numberRentListing
# there is data with in Airport West of highestRentListingPrice
# there is data with in Airport West of lowestRentListingPrice
# 3021
# there is data with in Albanvale of medianSoldPrice
# there is data with in Albanvale of numberSold
# there is data with in Albanvale of highestSoldPrice
# there is data with in Albanvale of lowestSoldPrice
# there is data with in Albanvale of 5thPercentileSoldPrice
# there is data with in Albanvale of 25thPercentileSoldPrice
# there is data with in Albanvale of 75thPercentileSoldPrice
# there is data with in Albanvale of 95thPercentileSoldPrice
# there is data with in Albanvale of medianSaleListingPrice
# there is data with in Albanvale of numberSaleListing
# there is data with in Albanvale of highestSaleListingPrice
# there is data with in Albanvale of lowestSaleListingPrice
# there is data with in Albanvale of auctionNumberAuctioned
# there is data with in Albanvale of auctionNumberSold
# there is data with in Albanvale of medianRentListingPrice
# there is data with in Albanvale of numberRentListing
# there is data with in Albanvale of highestRentListingPrice
# there is data with in Albanvale of lowestRentListingPrice
# 3206
# there is data with in Albert Park of medianSoldPrice
# there is data with in Albert Park of numberSold
# there is data with in Albert Park of highestSoldPrice
# there is data with in Albert Park of lowestSoldPrice
# there is data with in Albert Park of 5thPercentileSoldPrice
# there is data with in Albert Park of 25thPercentileSoldPrice
# there is data with in Albert Park of 75thPercentileSoldPrice
# there is data with in Albert Park of 95thPercentileSoldPrice
# there is data with in Albert Park of medianSaleListingPrice
# there is data with in Albert Park of numberSaleListing
# there is data with in Albert Park of highestSaleListingPrice
# there is data with in Albert Park of lowestSaleListingPrice
# there is data with in Albert Park of auctionNumberAuctioned
# there is data with in Albert Park of auctionNumberSold
# there is data with in Albert Park of medianRentListingPrice
# there is data with in Albert Park of numberRentListing
# there is data with in Albert Park of highestRentListingPrice
# there is data with in Albert Park of lowestRentListingPrice
# 3020
# there is data with in Albion of medianSoldPrice
# there is data with in Albion of numberSold
# there is data with in Albion of highestSoldPrice
# there is data with in Albion of lowestSoldPrice
# there is data with in Albion of 5thPercentileSoldPrice
# there is data with in Albion of 25thPercentileSoldPrice
# there is data with in Albion of 75thPercentileSoldPrice
# there is data with in Albion of 95thPercentileSoldPrice
# there is data with in Albion of medianSaleListingPrice
# there is data with in Albion of numberSaleListing
# there is data with in Albion of highestSaleListingPrice
# there is data with in Albion of lowestSaleListingPrice
# there is data with in Albion of auctionNumberAuctioned
# there is data with in Albion of auctionNumberSold
# there is data with in Albion of medianRentListingPrice
# there is data with in Albion of numberRentListing
# there is data with in Albion of highestRentListingPrice
# there is data with in Albion of lowestRentListingPrice
# 3078
# there is data with in Alphington of medianSoldPrice
# there is data with in Alphington of numberSold
# there is data with in Alphington of highestSoldPrice
# there is data with in Alphington of lowestSoldPrice
# there is data with in Alphington of 5thPercentileSoldPrice
# there is data with in Alphington of 25thPercentileSoldPrice
# there is data with in Alphington of 75thPercentileSoldPrice
# there is data with in Alphington of 95thPercentileSoldPrice
# there is data with in Alphington of medianSaleListingPrice
# there is data with in Alphington of numberSaleListing
# there is data with in Alphington of highestSaleListingPrice
# there is data with in Alphington of lowestSaleListingPrice
# there is data with in Alphington of auctionNumberAuctioned
# there is data with in Alphington of auctionNumberSold
# there is data with in Alphington of medianRentListingPrice
# there is data with in Alphington of numberRentListing
# there is data with in Alphington of highestRentListingPrice
# there is data with in Alphington of lowestRentListingPrice
# 3028
# there is data with in Altona Meadows of medianSoldPrice
# there is data with in Altona Meadows of numberSold
# there is data with in Altona Meadows of highestSoldPrice
# there is data with in Altona Meadows of lowestSoldPrice
# there is data with in Altona Meadows of 5thPercentileSoldPrice
# there is data with in Altona Meadows of 25thPercentileSoldPrice
# there is data with in Altona Meadows of 75thPercentileSoldPrice
# there is data with in Altona Meadows of 95thPercentileSoldPrice
# there is data with in Altona Meadows of medianSaleListingPrice
# there is data with in Altona Meadows of numberSaleListing
# there is data with in Altona Meadows of highestSaleListingPrice
# there is data with in Altona Meadows of lowestSaleListingPrice
# there is data with in Altona Meadows of auctionNumberAuctioned
# there is data with in Altona Meadows of auctionNumberSold
# there is data with in Altona Meadows of medianRentListingPrice
# there is data with in Altona Meadows of numberRentListing
# there is data with in Altona Meadows of highestRentListingPrice
# there is data with in Altona Meadows of lowestRentListingPrice
# 3025
# there is data with in Altona North of medianSoldPrice
# there is data with in Altona North of numberSold
# there is data with in Altona North of highestSoldPrice
# there is data with in Altona North of lowestSoldPrice
# there is data with in Altona North of 5thPercentileSoldPrice
# there is data with in Altona North of 25thPercentileSoldPrice
# there is data with in Altona North of 75thPercentileSoldPrice
# there is data with in Altona North of 95thPercentileSoldPrice
# there is data with in Altona North of medianSaleListingPrice
# there is data with in Altona North of numberSaleListing
# there is data with in Altona North of highestSaleListingPrice
# there is data with in Altona North of lowestSaleListingPrice
# there is data with in Altona North of auctionNumberAuctioned
# there is data with in Altona North of auctionNumberSold
# there is data with in Altona North of medianRentListingPrice
# there is data with in Altona North of numberRentListing
# there is data with in Altona North of highestRentListingPrice
# there is data with in Altona North of lowestRentListingPrice
# 3018
# there is data with in Altona of medianSoldPrice
# there is data with in Altona of numberSold
# there is data with in Altona of highestSoldPrice
# there is data with in Altona of lowestSoldPrice
# there is data with in Altona of 5thPercentileSoldPrice
# there is data with in Altona of 25thPercentileSoldPrice
# there is data with in Altona of 75thPercentileSoldPrice
# there is data with in Altona of 95thPercentileSoldPrice
# there is data with in Altona of medianSaleListingPrice
# there is data with in Altona of numberSaleListing
# there is data with in Altona of highestSaleListingPrice
# there is data with in Altona of lowestSaleListingPrice
# there is data with in Altona of auctionNumberAuctioned
# there is data with in Altona of auctionNumberSold
# there is data with in Altona of medianRentListingPrice
# there is data with in Altona of numberRentListing
# there is data with in Altona of highestRentListingPrice
# there is data with in Altona of lowestRentListingPrice
# 3022
# there is data with in Ardeer of medianSoldPrice
# there is data with in Ardeer of numberSold
# there is data with in Ardeer of highestSoldPrice
# there is data with in Ardeer of lowestSoldPrice
# there is data with in Ardeer of 5thPercentileSoldPrice
# there is data with in Ardeer of 25thPercentileSoldPrice
# there is data with in Ardeer of 75thPercentileSoldPrice
# there is data with in Ardeer of 95thPercentileSoldPrice
# there is data with in Ardeer of medianSaleListingPrice
# there is data with in Ardeer of numberSaleListing
# there is data with in Ardeer of highestSaleListingPrice
# there is data with in Ardeer of lowestSaleListingPrice
# there is data with in Ardeer of auctionNumberAuctioned
# there is data with in Ardeer of auctionNumberSold
# there is data with in Ardeer of medianRentListingPrice
# there is data with in Ardeer of numberRentListing
# there is data with in Ardeer of highestRentListingPrice
# there is data with in Ardeer of lowestRentListingPrice
# 3143
# there is data with in Armadale of medianSoldPrice
# there is data with in Armadale of numberSold
# there is data with in Armadale of highestSoldPrice
# there is data with in Armadale of lowestSoldPrice
# there is data with in Armadale of 5thPercentileSoldPrice
# there is data with in Armadale of 25thPercentileSoldPrice
# there is data with in Armadale of 75thPercentileSoldPrice
# there is data with in Armadale of 95thPercentileSoldPrice
# there is data with in Armadale of medianSaleListingPrice
# there is data with in Armadale of numberSaleListing
# there is data with in Armadale of highestSaleListingPrice
# there is data with in Armadale of lowestSaleListingPrice
# there is data with in Armadale of auctionNumberAuctioned
# there is data with in Armadale of auctionNumberSold
# there is data with in Armadale of medianRentListingPrice
# there is data with in Armadale of numberRentListing
# there is data with in Armadale of highestRentListingPrice
# there is data with in Armadale of lowestRentListingPrice
# 3936
# there is data with in Arthurs Seat of medianSoldPrice
# there is data with in Arthurs Seat of numberSold
# there is data with in Arthurs Seat of highestSoldPrice
# there is data with in Arthurs Seat of lowestSoldPrice
# there is data with in Arthurs Seat of 5thPercentileSoldPrice
# there is data with in Arthurs Seat of 25thPercentileSoldPrice
# there is data with in Arthurs Seat of 75thPercentileSoldPrice
# there is data with in Arthurs Seat of 95thPercentileSoldPrice
# there is data with in Arthurs Seat of medianSaleListingPrice
# there is data with in Arthurs Seat of numberSaleListing
# there is data with in Arthurs Seat of highestSaleListingPrice
# there is data with in Arthurs Seat of lowestSaleListingPrice
# there is data with in Arthurs Seat of auctionNumberAuctioned
# there is data with in Arthurs Seat of auctionNumberSold
# there is data with in Arthurs Seat of medianRentListingPrice
# there is data with in Arthurs Seat of numberRentListing
# there is data with in Arthurs Seat of highestRentListingPrice
# there is data with in Arthurs Seat of lowestRentListingPrice
# 3032
# there is data with in Ascot Vale of medianSoldPrice
# there is data with in Ascot Vale of numberSold
# there is data with in Ascot Vale of highestSoldPrice
# there is data with in Ascot Vale of lowestSoldPrice
# there is data with in Ascot Vale of 5thPercentileSoldPrice
# there is data with in Ascot Vale of 25thPercentileSoldPrice
# there is data with in Ascot Vale of 75thPercentileSoldPrice
# there is data with in Ascot Vale of 95thPercentileSoldPrice
# there is data with in Ascot Vale of medianSaleListingPrice
# there is data with in Ascot Vale of numberSaleListing
# there is data with in Ascot Vale of highestSaleListingPrice
# there is data with in Ascot Vale of lowestSaleListingPrice
# there is data with in Ascot Vale of auctionNumberAuctioned
# there is data with in Ascot Vale of auctionNumberSold
# there is data with in Ascot Vale of medianRentListingPrice
# there is data with in Ascot Vale of numberRentListing
# there is data with in Ascot Vale of highestRentListingPrice
# there is data with in Ascot Vale of lowestRentListingPrice
# 3147
# there is data with in Ashburton of medianSoldPrice
# there is data with in Ashburton of numberSold
# there is data with in Ashburton of highestSoldPrice
# there is data with in Ashburton of lowestSoldPrice
# there is data with in Ashburton of 5thPercentileSoldPrice
# there is data with in Ashburton of 25thPercentileSoldPrice
# there is data with in Ashburton of 75thPercentileSoldPrice
# there is data with in Ashburton of 95thPercentileSoldPrice
# there is data with in Ashburton of medianSaleListingPrice
# there is data with in Ashburton of numberSaleListing
# there is data with in Ashburton of highestSaleListingPrice
# there is data with in Ashburton of lowestSaleListingPrice
# there is data with in Ashburton of auctionNumberAuctioned
# there is data with in Ashburton of auctionNumberSold
# there is data with in Ashburton of medianRentListingPrice
# there is data with in Ashburton of numberRentListing
# there is data with in Ashburton of highestRentListingPrice
# there is data with in Ashburton of lowestRentListingPrice
# 3147
# there is data with in Ashwood of medianSoldPrice
# there is data with in Ashwood of numberSold
# there is data with in Ashwood of highestSoldPrice
# there is data with in Ashwood of lowestSoldPrice
# there is data with in Ashwood of 5thPercentileSoldPrice
# there is data with in Ashwood of 25thPercentileSoldPrice
# there is data with in Ashwood of 75thPercentileSoldPrice
# there is data with in Ashwood of 95thPercentileSoldPrice
# there is data with in Ashwood of medianSaleListingPrice
# there is data with in Ashwood of numberSaleListing
# there is data with in Ashwood of highestSaleListingPrice
# there is data with in Ashwood of lowestSaleListingPrice
# there is data with in Ashwood of auctionNumberAuctioned
# there is data with in Ashwood of auctionNumberSold
# there is data with in Ashwood of medianRentListingPrice
# there is data with in Ashwood of numberRentListing
# there is data with in Ashwood of highestRentListingPrice
# there is data with in Ashwood of lowestRentListingPrice
# 3195
# there is data with in Aspendale of medianSoldPrice
# there is data with in Aspendale of numberSold
# there is data with in Aspendale of highestSoldPrice
# there is data with in Aspendale of lowestSoldPrice
# there is data with in Aspendale of 5thPercentileSoldPrice
# there is data with in Aspendale of 25thPercentileSoldPrice
# there is data with in Aspendale of 75thPercentileSoldPrice
# there is data with in Aspendale of 95thPercentileSoldPrice
# there is data with in Aspendale of medianSaleListingPrice
# there is data with in Aspendale of numberSaleListing
# there is data with in Aspendale of highestSaleListingPrice
# there is data with in Aspendale of lowestSaleListingPrice
# there is data with in Aspendale of auctionNumberAuctioned
# there is data with in Aspendale of auctionNumberSold
# there is data with in Aspendale of medianRentListingPrice
# there is data with in Aspendale of numberRentListing
# there is data with in Aspendale of highestRentListingPrice
# there is data with in Aspendale of lowestRentListingPrice
# 3195
# there is data with in Aspendale Gardens of medianSoldPrice
# there is data with in Aspendale Gardens of numberSold
# there is data with in Aspendale Gardens of highestSoldPrice
# there is data with in Aspendale Gardens of lowestSoldPrice
# there is data with in Aspendale Gardens of 5thPercentileSoldPrice
# there is data with in Aspendale Gardens of 25thPercentileSoldPrice
# there is data with in Aspendale Gardens of 75thPercentileSoldPrice
# there is data with in Aspendale Gardens of 95thPercentileSoldPrice
# there is data with in Aspendale Gardens of medianSaleListingPrice
# there is data with in Aspendale Gardens of numberSaleListing
# there is data with in Aspendale Gardens of highestSaleListingPrice
# there is data with in Aspendale Gardens of lowestSaleListingPrice
# there is data with in Aspendale Gardens of auctionNumberAuctioned
# there is data with in Aspendale Gardens of auctionNumberSold
# there is data with in Aspendale Gardens of medianRentListingPrice
# there is data with in Aspendale Gardens of numberRentListing
# there is data with in Aspendale Gardens of highestRentListingPrice
# there is data with in Aspendale Gardens of lowestRentListingPrice
# 3049
# there is data with in Attwood of medianSoldPrice
# there is data with in Attwood of numberSold
# there is data with in Attwood of highestSoldPrice
# there is data with in Attwood of lowestSoldPrice
# there is data with in Attwood of 5thPercentileSoldPrice
# there is data with in Attwood of 25thPercentileSoldPrice
# there is data with in Attwood of 75thPercentileSoldPrice
# there is data with in Attwood of 95thPercentileSoldPrice
# there is data with in Attwood of medianSaleListingPrice
# there is data with in Attwood of numberSaleListing
# there is data with in Attwood of highestSaleListingPrice
# there is data with in Attwood of lowestSaleListingPrice
# there is data with in Attwood of auctionNumberAuctioned
# there is data with in Attwood of auctionNumberSold
# there is data with in Attwood of medianRentListingPrice
# there is data with in Attwood of numberRentListing
# there is data with in Attwood of highestRentListingPrice
# there is data with in Attwood of lowestRentListingPrice
# 3034
# there is data with in Avondale Heights of medianSoldPrice
# there is data with in Avondale Heights of numberSold
# there is data with in Avondale Heights of highestSoldPrice
# there is data with in Avondale Heights of lowestSoldPrice
# there is data with in Avondale Heights of 5thPercentileSoldPrice
# there is data with in Avondale Heights of 25thPercentileSoldPrice
# there is data with in Avondale Heights of 75thPercentileSoldPrice
# there is data with in Avondale Heights of 95thPercentileSoldPrice
# there is data with in Avondale Heights of medianSaleListingPrice
# there is data with in Avondale Heights of numberSaleListing
# there is data with in Avondale Heights of highestSaleListingPrice
# there is data with in Avondale Heights of lowestSaleListingPrice
# there is data with in Avondale Heights of auctionNumberAuctioned
# there is data with in Avondale Heights of auctionNumberSold
# there is data with in Avondale Heights of medianRentListingPrice
# there is data with in Avondale Heights of numberRentListing
# there is data with in Avondale Heights of highestRentListingPrice
# there is data with in Avondale Heights of lowestRentListingPrice
# 3782
# there is data with in Avonsleigh of medianSoldPrice
# there is data with in Avonsleigh of numberSold
# there is data with in Avonsleigh of highestSoldPrice
# there is data with in Avonsleigh of lowestSoldPrice
# there is data with in Avonsleigh of 5thPercentileSoldPrice
# there is data with in Avonsleigh of 25thPercentileSoldPrice
# there is data with in Avonsleigh of 75thPercentileSoldPrice
# there is data with in Avonsleigh of 95thPercentileSoldPrice
# there is data with in Avonsleigh of medianSaleListingPrice
# there is data with in Avonsleigh of numberSaleListing
# there is data with in Avonsleigh of highestSaleListingPrice
# there is data with in Avonsleigh of lowestSaleListingPrice
# there is data with in Avonsleigh of auctionNumberAuctioned
# there is data with in Avonsleigh of auctionNumberSold
# there is data with in Avonsleigh of medianRentListingPrice
# there is data with in Avonsleigh of numberRentListing
# there is data with in Avonsleigh of highestRentListingPrice
# there is data with in Avonsleigh of lowestRentListingPrice
# 3183
# there is data with in Balaclava of medianSoldPrice
# there is data with in Balaclava of numberSold
# there is data with in Balaclava of highestSoldPrice
# there is data with in Balaclava of lowestSoldPrice
# there is data with in Balaclava of 5thPercentileSoldPrice
# there is data with in Balaclava of 25thPercentileSoldPrice
# there is data with in Balaclava of 75thPercentileSoldPrice
# there is data with in Balaclava of 95thPercentileSoldPrice
# there is data with in Balaclava of medianSaleListingPrice
# there is data with in Balaclava of numberSaleListing
# there is data with in Balaclava of highestSaleListingPrice
# there is data with in Balaclava of lowestSaleListingPrice
# there is data with in Balaclava of auctionNumberAuctioned
# there is data with in Balaclava of auctionNumberSold
# there is data with in Balaclava of medianRentListingPrice
# there is data with in Balaclava of numberRentListing
# there is data with in Balaclava of highestRentListingPrice
# there is data with in Balaclava of lowestRentListingPrice
# 3103
# there is data with in Balwyn of medianSoldPrice
# there is data with in Balwyn of numberSold
# there is data with in Balwyn of highestSoldPrice
# there is data with in Balwyn of lowestSoldPrice
# there is data with in Balwyn of 5thPercentileSoldPrice
# there is data with in Balwyn of 25thPercentileSoldPrice
# there is data with in Balwyn of 75thPercentileSoldPrice
# there is data with in Balwyn of 95thPercentileSoldPrice
# there is data with in Balwyn of medianSaleListingPrice
# there is data with in Balwyn of numberSaleListing
# there is data with in Balwyn of highestSaleListingPrice
# there is data with in Balwyn of lowestSaleListingPrice
# there is data with in Balwyn of auctionNumberAuctioned
# there is data with in Balwyn of auctionNumberSold
# there is data with in Balwyn of medianRentListingPrice
# there is data with in Balwyn of numberRentListing
# there is data with in Balwyn of highestRentListingPrice
# there is data with in Balwyn of lowestRentListingPrice
# 3104
# there is data with in Balwyn North of medianSoldPrice
# there is data with in Balwyn North of numberSold
# there is data with in Balwyn North of highestSoldPrice
# there is data with in Balwyn North of lowestSoldPrice
# there is data with in Balwyn North of 5thPercentileSoldPrice
# there is data with in Balwyn North of 25thPercentileSoldPrice
# there is data with in Balwyn North of 75thPercentileSoldPrice
# there is data with in Balwyn North of 95thPercentileSoldPrice
# there is data with in Balwyn North of medianSaleListingPrice
# there is data with in Balwyn North of numberSaleListing
# there is data with in Balwyn North of highestSaleListingPrice
# there is data with in Balwyn North of lowestSaleListingPrice
# there is data with in Balwyn North of auctionNumberAuctioned
# there is data with in Balwyn North of auctionNumberSold
# there is data with in Balwyn North of medianRentListingPrice
# there is data with in Balwyn North of numberRentListing
# there is data with in Balwyn North of highestRentListingPrice
# there is data with in Balwyn North of lowestRentListingPrice
# 3175
# there is data with in Bangholme of medianSoldPrice
# there is data with in Bangholme of numberSold
# there is data with in Bangholme of highestSoldPrice
# there is data with in Bangholme of lowestSoldPrice
# there is data with in Bangholme of 5thPercentileSoldPrice
# there is data with in Bangholme of 25thPercentileSoldPrice
# there is data with in Bangholme of 75thPercentileSoldPrice
# there is data with in Bangholme of 95thPercentileSoldPrice
# there is data with in Bangholme of medianSaleListingPrice
# there is data with in Bangholme of numberSaleListing
# there is data with in Bangholme of highestSaleListingPrice
# there is data with in Bangholme of lowestSaleListingPrice
# there is data with in Bangholme of auctionNumberAuctioned
# there is data with in Bangholme of auctionNumberSold
# there is data with in Bangholme of medianRentListingPrice
# there is data with in Bangholme of numberRentListing
# there is data with in Bangholme of highestRentListingPrice
# there is data with in Bangholme of lowestRentListingPrice
# 3911
# there is data with in Baxter of medianSoldPrice
# there is data with in Baxter of numberSold
# there is data with in Baxter of highestSoldPrice
# there is data with in Baxter of lowestSoldPrice
# there is data with in Baxter of 5thPercentileSoldPrice
# there is data with in Baxter of 25thPercentileSoldPrice
# there is data with in Baxter of 75thPercentileSoldPrice
# there is data with in Baxter of 95thPercentileSoldPrice
# there is data with in Baxter of medianSaleListingPrice
# there is data with in Baxter of numberSaleListing
# there is data with in Baxter of highestSaleListingPrice
# there is data with in Baxter of lowestSaleListingPrice
# there is data with in Baxter of auctionNumberAuctioned
# there is data with in Baxter of auctionNumberSold
# there is data with in Baxter of medianRentListingPrice
# there is data with in Baxter of numberRentListing
# there is data with in Baxter of highestRentListingPrice
# there is data with in Baxter of lowestRentListingPrice
# 3153
# there is data with in Bayswater of medianSoldPrice
# there is data with in Bayswater of numberSold
# there is data with in Bayswater of highestSoldPrice
# there is data with in Bayswater of lowestSoldPrice
# there is data with in Bayswater of 5thPercentileSoldPrice
# there is data with in Bayswater of 25thPercentileSoldPrice
# there is data with in Bayswater of 75thPercentileSoldPrice
# there is data with in Bayswater of 95thPercentileSoldPrice
# there is data with in Bayswater of medianSaleListingPrice
# there is data with in Bayswater of numberSaleListing
# there is data with in Bayswater of highestSaleListingPrice
# there is data with in Bayswater of lowestSaleListingPrice
# there is data with in Bayswater of auctionNumberAuctioned
# there is data with in Bayswater of auctionNumberSold
# there is data with in Bayswater of medianRentListingPrice
# there is data with in Bayswater of numberRentListing
# there is data with in Bayswater of highestRentListingPrice
# there is data with in Bayswater of lowestRentListingPrice
# 3153
# there is data with in Bayswater North of medianSoldPrice
# there is data with in Bayswater North of numberSold
# there is data with in Bayswater North of highestSoldPrice
# there is data with in Bayswater North of lowestSoldPrice
# there is data with in Bayswater North of 5thPercentileSoldPrice
# there is data with in Bayswater North of 25thPercentileSoldPrice
# there is data with in Bayswater North of 75thPercentileSoldPrice
# there is data with in Bayswater North of 95thPercentileSoldPrice
# there is data with in Bayswater North of medianSaleListingPrice
# there is data with in Bayswater North of numberSaleListing
# there is data with in Bayswater North of highestSaleListingPrice
# there is data with in Bayswater North of lowestSaleListingPrice
# there is data with in Bayswater North of auctionNumberAuctioned
# there is data with in Bayswater North of auctionNumberSold
# there is data with in Bayswater North of medianRentListingPrice
# there is data with in Bayswater North of numberRentListing
# there is data with in Bayswater North of highestRentListingPrice
# there is data with in Bayswater North of lowestRentListingPrice
# 3807
# there is data with in Beaconsfield of medianSoldPrice
# there is data with in Beaconsfield of numberSold
# there is data with in Beaconsfield of highestSoldPrice
# there is data with in Beaconsfield of lowestSoldPrice
# there is data with in Beaconsfield of 5thPercentileSoldPrice
# there is data with in Beaconsfield of 25thPercentileSoldPrice
# there is data with in Beaconsfield of 75thPercentileSoldPrice
# there is data with in Beaconsfield of 95thPercentileSoldPrice
# there is data with in Beaconsfield of medianSaleListingPrice
# there is data with in Beaconsfield of numberSaleListing
# there is data with in Beaconsfield of highestSaleListingPrice
# there is data with in Beaconsfield of lowestSaleListingPrice
# there is data with in Beaconsfield of auctionNumberAuctioned
# there is data with in Beaconsfield of auctionNumberSold
# there is data with in Beaconsfield of medianRentListingPrice
# there is data with in Beaconsfield of numberRentListing
# there is data with in Beaconsfield of highestRentListingPrice
# there is data with in Beaconsfield of lowestRentListingPrice
# 3193
# there is data with in Beaumaris of medianSoldPrice
# there is data with in Beaumaris of numberSold
# there is data with in Beaumaris of highestSoldPrice
# there is data with in Beaumaris of lowestSoldPrice
# there is data with in Beaumaris of 5thPercentileSoldPrice
# there is data with in Beaumaris of 25thPercentileSoldPrice
# there is data with in Beaumaris of 75thPercentileSoldPrice
# there is data with in Beaumaris of 95thPercentileSoldPrice
# there is data with in Beaumaris of medianSaleListingPrice
# there is data with in Beaumaris of numberSaleListing
# there is data with in Beaumaris of highestSaleListingPrice
# there is data with in Beaumaris of lowestSaleListingPrice
# there is data with in Beaumaris of auctionNumberAuctioned
# there is data with in Beaumaris of auctionNumberSold
# there is data with in Beaumaris of medianRentListingPrice
# there is data with in Beaumaris of numberRentListing
# there is data with in Beaumaris of highestRentListingPrice
# there is data with in Beaumaris of lowestRentListingPrice
# 3160
# there is data with in Belgrave of medianSoldPrice
# there is data with in Belgrave of numberSold
# there is data with in Belgrave of highestSoldPrice
# there is data with in Belgrave of lowestSoldPrice
# there is data with in Belgrave of 5thPercentileSoldPrice
# there is data with in Belgrave of 25thPercentileSoldPrice
# there is data with in Belgrave of 75thPercentileSoldPrice
# there is data with in Belgrave of 95thPercentileSoldPrice
# there is data with in Belgrave of medianSaleListingPrice
# there is data with in Belgrave of numberSaleListing
# there is data with in Belgrave of highestSaleListingPrice
# there is data with in Belgrave of lowestSaleListingPrice
# there is data with in Belgrave of auctionNumberAuctioned
# there is data with in Belgrave of auctionNumberSold
# there is data with in Belgrave of medianRentListingPrice
# there is data with in Belgrave of numberRentListing
# there is data with in Belgrave of highestRentListingPrice
# there is data with in Belgrave of lowestRentListingPrice
# 3160
# there is data with in Belgrave Heights of medianSoldPrice
# there is data with in Belgrave Heights of numberSold
# there is data with in Belgrave Heights of highestSoldPrice
# there is data with in Belgrave Heights of lowestSoldPrice
# there is data with in Belgrave Heights of 5thPercentileSoldPrice
# there is data with in Belgrave Heights of 25thPercentileSoldPrice
# there is data with in Belgrave Heights of 75thPercentileSoldPrice
# there is data with in Belgrave Heights of 95thPercentileSoldPrice
# there is data with in Belgrave Heights of medianSaleListingPrice
# there is data with in Belgrave Heights of numberSaleListing
# there is data with in Belgrave Heights of highestSaleListingPrice
# there is data with in Belgrave Heights of lowestSaleListingPrice
# there is data with in Belgrave Heights of auctionNumberAuctioned
# there is data with in Belgrave Heights of auctionNumberSold
# there is data with in Belgrave Heights of medianRentListingPrice
# there is data with in Belgrave Heights of numberRentListing
# there is data with in Belgrave Heights of highestRentListingPrice
# there is data with in Belgrave Heights of lowestRentListingPrice
# 3160
# there is data with in Belgrave South of medianSoldPrice
# there is data with in Belgrave South of numberSold
# there is data with in Belgrave South of highestSoldPrice
# there is data with in Belgrave South of lowestSoldPrice
# there is data with in Belgrave South of 5thPercentileSoldPrice
# there is data with in Belgrave South of 25thPercentileSoldPrice
# there is data with in Belgrave South of 75thPercentileSoldPrice
# there is data with in Belgrave South of 95thPercentileSoldPrice
# there is data with in Belgrave South of medianSaleListingPrice
# there is data with in Belgrave South of numberSaleListing
# there is data with in Belgrave South of highestSaleListingPrice
# there is data with in Belgrave South of lowestSaleListingPrice
# there is data with in Belgrave South of auctionNumberAuctioned
# there is data with in Belgrave South of auctionNumberSold
# there is data with in Belgrave South of medianRentListingPrice
# there is data with in Belgrave South of numberRentListing
# there is data with in Belgrave South of highestRentListingPrice
# there is data with in Belgrave South of lowestRentListingPrice
# 3081
# there is data with in Bellfield of medianSoldPrice
# there is data with in Bellfield of numberSold
# there is data with in Bellfield of highestSoldPrice
# there is data with in Bellfield of lowestSoldPrice
# there is data with in Bellfield of 5thPercentileSoldPrice
# there is data with in Bellfield of 25thPercentileSoldPrice
# there is data with in Bellfield of 75thPercentileSoldPrice
# there is data with in Bellfield of 95thPercentileSoldPrice
# there is data with in Bellfield of medianSaleListingPrice
# there is data with in Bellfield of numberSaleListing
# there is data with in Bellfield of highestSaleListingPrice
# there is data with in Bellfield of lowestSaleListingPrice
# there is data with in Bellfield of auctionNumberAuctioned
# there is data with in Bellfield of auctionNumberSold
# there is data with in Bellfield of medianRentListingPrice
# there is data with in Bellfield of numberRentListing
# there is data with in Bellfield of highestRentListingPrice
# there is data with in Bellfield of lowestRentListingPrice
# 3204
# there is data with in Bentleigh of medianSoldPrice
# there is data with in Bentleigh of numberSold
# there is data with in Bentleigh of highestSoldPrice
# there is data with in Bentleigh of lowestSoldPrice
# there is data with in Bentleigh of 5thPercentileSoldPrice
# there is data with in Bentleigh of 25thPercentileSoldPrice
# there is data with in Bentleigh of 75thPercentileSoldPrice
# there is data with in Bentleigh of 95thPercentileSoldPrice
# there is data with in Bentleigh of medianSaleListingPrice
# there is data with in Bentleigh of numberSaleListing
# there is data with in Bentleigh of highestSaleListingPrice
# there is data with in Bentleigh of lowestSaleListingPrice
# there is data with in Bentleigh of auctionNumberAuctioned
# there is data with in Bentleigh of auctionNumberSold
# there is data with in Bentleigh of medianRentListingPrice
# there is data with in Bentleigh of numberRentListing
# there is data with in Bentleigh of highestRentListingPrice
# there is data with in Bentleigh of lowestRentListingPrice
# 3165
# there is data with in Bentleigh East of medianSoldPrice
# there is data with in Bentleigh East of numberSold
# there is data with in Bentleigh East of highestSoldPrice
# there is data with in Bentleigh East of lowestSoldPrice
# there is data with in Bentleigh East of 5thPercentileSoldPrice
# there is data with in Bentleigh East of 25thPercentileSoldPrice
# there is data with in Bentleigh East of 75thPercentileSoldPrice
# there is data with in Bentleigh East of 95thPercentileSoldPrice
# there is data with in Bentleigh East of medianSaleListingPrice
# there is data with in Bentleigh East of numberSaleListing
# there is data with in Bentleigh East of highestSaleListingPrice
# there is data with in Bentleigh East of lowestSaleListingPrice
# there is data with in Bentleigh East of auctionNumberAuctioned
# there is data with in Bentleigh East of auctionNumberSold
# there is data with in Bentleigh East of medianRentListingPrice
# there is data with in Bentleigh East of numberRentListing
# there is data with in Bentleigh East of highestRentListingPrice
# there is data with in Bentleigh East of lowestRentListingPrice
# 3806
# there is data with in Berwick of medianSoldPrice
# there is data with in Berwick of numberSold
# there is data with in Berwick of highestSoldPrice
# there is data with in Berwick of lowestSoldPrice
# there is data with in Berwick of 5thPercentileSoldPrice
# there is data with in Berwick of 25thPercentileSoldPrice
# there is data with in Berwick of 75thPercentileSoldPrice
# there is data with in Berwick of 95thPercentileSoldPrice
# there is data with in Berwick of medianSaleListingPrice
# there is data with in Berwick of numberSaleListing
# there is data with in Berwick of highestSaleListingPrice
# there is data with in Berwick of lowestSaleListingPrice
# there is data with in Berwick of auctionNumberAuctioned
# there is data with in Berwick of auctionNumberSold
# there is data with in Berwick of medianRentListingPrice
# there is data with in Berwick of numberRentListing
# there is data with in Berwick of highestRentListingPrice
# there is data with in Berwick of lowestRentListingPrice
# 3918
# there is data with in Bittern of medianSoldPrice
# there is data with in Bittern of numberSold
# there is data with in Bittern of highestSoldPrice
# there is data with in Bittern of lowestSoldPrice
# there is data with in Bittern of 5thPercentileSoldPrice
# there is data with in Bittern of 25thPercentileSoldPrice
# there is data with in Bittern of 75thPercentileSoldPrice
# there is data with in Bittern of 95thPercentileSoldPrice
# there is data with in Bittern of medianSaleListingPrice
# there is data with in Bittern of numberSaleListing
# there is data with in Bittern of highestSaleListingPrice
# there is data with in Bittern of lowestSaleListingPrice
# there is data with in Bittern of auctionNumberAuctioned
# there is data with in Bittern of auctionNumberSold
# there is data with in Bittern of medianRentListingPrice
# there is data with in Bittern of numberRentListing
# there is data with in Bittern of highestRentListingPrice
# there is data with in Bittern of lowestRentListingPrice
# 3193
# there is data with in Black Rock of medianSoldPrice
# there is data with in Black Rock of numberSold
# there is data with in Black Rock of highestSoldPrice
# there is data with in Black Rock of lowestSoldPrice
# there is data with in Black Rock of 5thPercentileSoldPrice
# there is data with in Black Rock of 25thPercentileSoldPrice
# there is data with in Black Rock of 75thPercentileSoldPrice
# there is data with in Black Rock of 95thPercentileSoldPrice
# there is data with in Black Rock of medianSaleListingPrice
# there is data with in Black Rock of numberSaleListing
# there is data with in Black Rock of highestSaleListingPrice
# there is data with in Black Rock of lowestSaleListingPrice
# there is data with in Black Rock of auctionNumberAuctioned
# there is data with in Black Rock of auctionNumberSold
# there is data with in Black Rock of medianRentListingPrice
# there is data with in Black Rock of numberRentListing
# there is data with in Black Rock of highestRentListingPrice
# there is data with in Black Rock of lowestRentListingPrice
# 3130
# there is data with in Blackburn of medianSoldPrice
# there is data with in Blackburn of numberSold
# there is data with in Blackburn of highestSoldPrice
# there is data with in Blackburn of lowestSoldPrice
# there is data with in Blackburn of 5thPercentileSoldPrice
# there is data with in Blackburn of 25thPercentileSoldPrice
# there is data with in Blackburn of 75thPercentileSoldPrice
# there is data with in Blackburn of 95thPercentileSoldPrice
# there is data with in Blackburn of medianSaleListingPrice
# there is data with in Blackburn of numberSaleListing
# there is data with in Blackburn of highestSaleListingPrice
# there is data with in Blackburn of lowestSaleListingPrice
# there is data with in Blackburn of auctionNumberAuctioned
# there is data with in Blackburn of auctionNumberSold
# there is data with in Blackburn of medianRentListingPrice
# there is data with in Blackburn of numberRentListing
# there is data with in Blackburn of highestRentListingPrice
# there is data with in Blackburn of lowestRentListingPrice
# 3130
# there is data with in Blackburn North of medianSoldPrice
# there is data with in Blackburn North of numberSold
# there is data with in Blackburn North of highestSoldPrice
# there is data with in Blackburn North of lowestSoldPrice
# there is data with in Blackburn North of 5thPercentileSoldPrice
# there is data with in Blackburn North of 25thPercentileSoldPrice
# there is data with in Blackburn North of 75thPercentileSoldPrice
# there is data with in Blackburn North of 95thPercentileSoldPrice
# there is data with in Blackburn North of medianSaleListingPrice
# there is data with in Blackburn North of numberSaleListing
# there is data with in Blackburn North of highestSaleListingPrice
# there is data with in Blackburn North of lowestSaleListingPrice
# there is data with in Blackburn North of auctionNumberAuctioned
# there is data with in Blackburn North of auctionNumberSold
# there is data with in Blackburn North of medianRentListingPrice
# there is data with in Blackburn North of numberRentListing
# there is data with in Blackburn North of highestRentListingPrice
# there is data with in Blackburn North of lowestRentListingPrice
# 3130
# there is data with in Blackburn South of medianSoldPrice
# there is data with in Blackburn South of numberSold
# there is data with in Blackburn South of highestSoldPrice
# there is data with in Blackburn South of lowestSoldPrice
# there is data with in Blackburn South of 5thPercentileSoldPrice
# there is data with in Blackburn South of 25thPercentileSoldPrice
# there is data with in Blackburn South of 75thPercentileSoldPrice
# there is data with in Blackburn South of 95thPercentileSoldPrice
# there is data with in Blackburn South of medianSaleListingPrice
# there is data with in Blackburn South of numberSaleListing
# there is data with in Blackburn South of highestSaleListingPrice
# there is data with in Blackburn South of lowestSaleListingPrice
# there is data with in Blackburn South of auctionNumberAuctioned
# there is data with in Blackburn South of auctionNumberSold
# there is data with in Blackburn South of medianRentListingPrice
# there is data with in Blackburn South of numberRentListing
# there is data with in Blackburn South of highestRentListingPrice
# there is data with in Blackburn South of lowestRentListingPrice
# 3942
# there is data with in Blairgowrie of medianSoldPrice
# there is data with in Blairgowrie of numberSold
# there is data with in Blairgowrie of highestSoldPrice
# there is data with in Blairgowrie of lowestSoldPrice
# there is data with in Blairgowrie of 5thPercentileSoldPrice
# there is data with in Blairgowrie of 25thPercentileSoldPrice
# there is data with in Blairgowrie of 75thPercentileSoldPrice
# there is data with in Blairgowrie of 95thPercentileSoldPrice
# there is data with in Blairgowrie of medianSaleListingPrice
# there is data with in Blairgowrie of numberSaleListing
# there is data with in Blairgowrie of highestSaleListingPrice
# there is data with in Blairgowrie of lowestSaleListingPrice
# there is data with in Blairgowrie of auctionNumberAuctioned
# there is data with in Blairgowrie of auctionNumberSold
# there is data with in Blairgowrie of medianRentListingPrice
# there is data with in Blairgowrie of numberRentListing
# there is data with in Blairgowrie of highestRentListingPrice
# there is data with in Blairgowrie of lowestRentListingPrice
# 3196
# there is data with in Bonbeach of medianSoldPrice
# there is data with in Bonbeach of numberSold
# there is data with in Bonbeach of highestSoldPrice
# there is data with in Bonbeach of lowestSoldPrice
# there is data with in Bonbeach of 5thPercentileSoldPrice
# there is data with in Bonbeach of 25thPercentileSoldPrice
# there is data with in Bonbeach of 75thPercentileSoldPrice
# there is data with in Bonbeach of 95thPercentileSoldPrice
# there is data with in Bonbeach of medianSaleListingPrice
# there is data with in Bonbeach of numberSaleListing
# there is data with in Bonbeach of highestSaleListingPrice
# there is data with in Bonbeach of lowestSaleListingPrice
# there is data with in Bonbeach of auctionNumberAuctioned
# there is data with in Bonbeach of auctionNumberSold
# there is data with in Bonbeach of medianRentListingPrice
# there is data with in Bonbeach of numberRentListing
# there is data with in Bonbeach of highestRentListingPrice
# there is data with in Bonbeach of lowestRentListingPrice
# 3155
# there is data with in Boronia of medianSoldPrice
# there is data with in Boronia of numberSold
# there is data with in Boronia of highestSoldPrice
# there is data with in Boronia of lowestSoldPrice
# there is data with in Boronia of 5thPercentileSoldPrice
# there is data with in Boronia of 25thPercentileSoldPrice
# there is data with in Boronia of 75thPercentileSoldPrice
# there is data with in Boronia of 95thPercentileSoldPrice
# there is data with in Boronia of medianSaleListingPrice
# there is data with in Boronia of numberSaleListing
# there is data with in Boronia of highestSaleListingPrice
# there is data with in Boronia of lowestSaleListingPrice
# there is data with in Boronia of auctionNumberAuctioned
# there is data with in Boronia of auctionNumberSold
# there is data with in Boronia of medianRentListingPrice
# there is data with in Boronia of numberRentListing
# there is data with in Boronia of highestRentListingPrice
# there is data with in Boronia of lowestRentListingPrice
# 3128
# there is data with in Box Hill of medianSoldPrice
# there is data with in Box Hill of numberSold
# there is data with in Box Hill of highestSoldPrice
# there is data with in Box Hill of lowestSoldPrice
# there is data with in Box Hill of 5thPercentileSoldPrice
# there is data with in Box Hill of 25thPercentileSoldPrice
# there is data with in Box Hill of 75thPercentileSoldPrice
# there is data with in Box Hill of 95thPercentileSoldPrice
# there is data with in Box Hill of medianSaleListingPrice
# there is data with in Box Hill of numberSaleListing
# there is data with in Box Hill of highestSaleListingPrice
# there is data with in Box Hill of lowestSaleListingPrice
# there is data with in Box Hill of auctionNumberAuctioned
# there is data with in Box Hill of auctionNumberSold
# there is data with in Box Hill of medianRentListingPrice
# there is data with in Box Hill of numberRentListing
# there is data with in Box Hill of highestRentListingPrice
# there is data with in Box Hill of lowestRentListingPrice
# 3129
# there is data with in Box Hill North of medianSoldPrice
# there is data with in Box Hill North of numberSold
# there is data with in Box Hill North of highestSoldPrice
# there is data with in Box Hill North of lowestSoldPrice
# there is data with in Box Hill North of 5thPercentileSoldPrice
# there is data with in Box Hill North of 25thPercentileSoldPrice
# there is data with in Box Hill North of 75thPercentileSoldPrice
# there is data with in Box Hill North of 95thPercentileSoldPrice
# there is data with in Box Hill North of medianSaleListingPrice
# there is data with in Box Hill North of numberSaleListing
# there is data with in Box Hill North of highestSaleListingPrice
# there is data with in Box Hill North of lowestSaleListingPrice
# ...
# 3338
# there is data with in Brookfield of medianSoldPrice
# there is data with in Brookfield of numberSold
# there is data with in Brookfield of highestSoldPrice
# there is data with in Brookfield of lowestSoldPrice
# there is data with in Brookfield of 5thPercentileSoldPrice
# there is data with in Brookfield of 25thPercentileSoldPrice
# there is data with in Brookfield of 75thPercentileSoldPrice
# there is data with in Brookfield of 95thPercentileSoldPrice
# there is data with in Brookfield of medianSaleListingPrice
# there is data with in Brookfield of numberSaleListing
# there is data with in Brookfield of highestSaleListingPrice
# there is data with in Brookfield of lowestSaleListingPrice
# there is data with in Brookfield of auctionNumberAuctioned
# there is data with in Brookfield of auctionNumberSold
# there is data with in Brookfield of medianRentListingPrice
# there is data with in Brookfield of numberRentListing
# there is data with in Brookfield of highestRentListingPrice
# there is data with in Brookfield of lowestRentListingPrice
# 3012
# there is data with in Brooklyn of medianSoldPrice
# there is data with in Brooklyn of numberSold
# there is data with in Brooklyn of highestSoldPrice
# there is data with in Brooklyn of lowestSoldPrice
# there is data with in Brooklyn of 5thPercentileSoldPrice
# there is data with in Brooklyn of 25thPercentileSoldPrice
# there is data with in Brooklyn of 75thPercentileSoldPrice
# there is data with in Brooklyn of 95thPercentileSoldPrice
# there is data with in Brooklyn of medianSaleListingPrice
# there is data with in Brooklyn of numberSaleListing
# there is data with in Brooklyn of highestSaleListingPrice
# there is data with in Brooklyn of lowestSaleListingPrice
# there is data with in Brooklyn of auctionNumberAuctioned
# there is data with in Brooklyn of auctionNumberSold
# there is data with in Brooklyn of medianRentListingPrice
# there is data with in Brooklyn of numberRentListing
# there is data with in Brooklyn of highestRentListingPrice
# there is data with in Brooklyn of lowestRentListingPrice
# 3056
# there is data with in Brunswick of medianSoldPrice
# there is data with in Brunswick of numberSold
# there is data with in Brunswick of highestSoldPrice
# there is data with in Brunswick of lowestSoldPrice
# there is data with in Brunswick of 5thPercentileSoldPrice
# there is data with in Brunswick of 25thPercentileSoldPrice
# there is data with in Brunswick of 75thPercentileSoldPrice
# there is data with in Brunswick of 95thPercentileSoldPrice
# there is data with in Brunswick of medianSaleListingPrice
# there is data with in Brunswick of numberSaleListing
# there is data with in Brunswick of highestSaleListingPrice
# there is data with in Brunswick of lowestSaleListingPrice
# there is data with in Brunswick of auctionNumberAuctioned
# there is data with in Brunswick of auctionNumberSold
# there is data with in Brunswick of medianRentListingPrice
# there is data with in Brunswick of numberRentListing
# there is data with in Brunswick of highestRentListingPrice
# there is data with in Brunswick of lowestRentListingPrice
# 3057
# there is data with in Brunswick East of medianSoldPrice
# there is data with in Brunswick East of numberSold
# there is data with in Brunswick East of highestSoldPrice
# there is data with in Brunswick East of lowestSoldPrice
# there is data with in Brunswick East of 5thPercentileSoldPrice
# there is data with in Brunswick East of 25thPercentileSoldPrice
# there is data with in Brunswick East of 75thPercentileSoldPrice
# there is data with in Brunswick East of 95thPercentileSoldPrice
# there is data with in Brunswick East of medianSaleListingPrice
# there is data with in Brunswick East of numberSaleListing
# there is data with in Brunswick East of highestSaleListingPrice
# there is data with in Brunswick East of lowestSaleListingPrice
# there is data with in Brunswick East of auctionNumberAuctioned
# there is data with in Brunswick East of auctionNumberSold
# there is data with in Brunswick East of medianRentListingPrice
# there is data with in Brunswick East of numberRentListing
# there is data with in Brunswick East of highestRentListingPrice
# there is data with in Brunswick East of lowestRentListingPrice
# 3055
# there is data with in Brunswick West of medianSoldPrice
# there is data with in Brunswick West of numberSold
# there is data with in Brunswick West of highestSoldPrice
# there is data with in Brunswick West of lowestSoldPrice
# there is data with in Brunswick West of 5thPercentileSoldPrice
# there is data with in Brunswick West of 25thPercentileSoldPrice
# there is data with in Brunswick West of 75thPercentileSoldPrice
# there is data with in Brunswick West of 95thPercentileSoldPrice
# there is data with in Brunswick West of medianSaleListingPrice
# there is data with in Brunswick West of numberSaleListing
# there is data with in Brunswick West of highestSaleListingPrice
# there is data with in Brunswick West of lowestSaleListingPrice
# there is data with in Brunswick West of auctionNumberAuctioned
# there is data with in Brunswick West of auctionNumberSold
# there is data with in Brunswick West of medianRentListingPrice
# there is data with in Brunswick West of numberRentListing
# there is data with in Brunswick West of highestRentListingPrice
# there is data with in Brunswick West of lowestRentListingPrice
# 3428
# there is data with in Bulla of medianSoldPrice
# there is data with in Bulla of numberSold
# there is data with in Bulla of highestSoldPrice
# there is data with in Bulla of lowestSoldPrice
# there is data with in Bulla of 5thPercentileSoldPrice
# there is data with in Bulla of 25thPercentileSoldPrice
# there is data with in Bulla of 75thPercentileSoldPrice
# there is data with in Bulla of 95thPercentileSoldPrice
# there is data with in Bulla of medianSaleListingPrice
# there is data with in Bulla of numberSaleListing
# there is data with in Bulla of highestSaleListingPrice
# there is data with in Bulla of lowestSaleListingPrice
# there is data with in Bulla of auctionNumberAuctioned
# there is data with in Bulla of auctionNumberSold
# there is data with in Bulla of medianRentListingPrice
# there is data with in Bulla of numberRentListing
# there is data with in Bulla of highestRentListingPrice
# there is data with in Bulla of lowestRentListingPrice
# 3105
# there is data with in Bulleen of medianSoldPrice
# there is data with in Bulleen of numberSold
# there is data with in Bulleen of highestSoldPrice
# there is data with in Bulleen of lowestSoldPrice
# there is data with in Bulleen of 5thPercentileSoldPrice
# there is data with in Bulleen of 25thPercentileSoldPrice
# there is data with in Bulleen of 75thPercentileSoldPrice
# there is data with in Bulleen of 95thPercentileSoldPrice
# there is data with in Bulleen of medianSaleListingPrice
# there is data with in Bulleen of numberSaleListing
# there is data with in Bulleen of highestSaleListingPrice
# there is data with in Bulleen of lowestSaleListingPrice
# there is data with in Bulleen of auctionNumberAuctioned
# there is data with in Bulleen of auctionNumberSold
# there is data with in Bulleen of medianRentListingPrice
# there is data with in Bulleen of numberRentListing
# there is data with in Bulleen of highestRentListingPrice
# there is data with in Bulleen of lowestRentListingPrice
# 3083
# there is data with in Bundoora of medianSoldPrice
# there is data with in Bundoora of numberSold
# there is data with in Bundoora of highestSoldPrice
# there is data with in Bundoora of lowestSoldPrice
# there is data with in Bundoora of 5thPercentileSoldPrice
# there is data with in Bundoora of 25thPercentileSoldPrice
# there is data with in Bundoora of 75thPercentileSoldPrice
# there is data with in Bundoora of 95thPercentileSoldPrice
# there is data with in Bundoora of medianSaleListingPrice
# there is data with in Bundoora of numberSaleListing
# there is data with in Bundoora of highestSaleListingPrice
# there is data with in Bundoora of lowestSaleListingPrice
# there is data with in Bundoora of auctionNumberAuctioned
# there is data with in Bundoora of auctionNumberSold
# there is data with in Bundoora of medianRentListingPrice
# there is data with in Bundoora of numberRentListing
# there is data with in Bundoora of highestRentListingPrice
# there is data with in Bundoora of lowestRentListingPrice
# 3121
# there is data with in Burnley of medianSoldPrice
# there is data with in Burnley of numberSold
# there is data with in Burnley of highestSoldPrice
# there is data with in Burnley of lowestSoldPrice
# there is data with in Burnley of 5thPercentileSoldPrice
# there is data with in Burnley of 25thPercentileSoldPrice
# there is data with in Burnley of 75thPercentileSoldPrice
# there is data with in Burnley of 95thPercentileSoldPrice
# there is data with in Burnley of medianSaleListingPrice
# there is data with in Burnley of numberSaleListing
# there is data with in Burnley of highestSaleListingPrice
# there is data with in Burnley of lowestSaleListingPrice
# there is data with in Burnley of auctionNumberAuctioned
# there is data with in Burnley of auctionNumberSold
# there is data with in Burnley of medianRentListingPrice
# there is data with in Burnley of numberRentListing
# there is data with in Burnley of highestRentListingPrice
# there is data with in Burnley of lowestRentListingPrice
# 3023
# there is data with in Burnside of medianSoldPrice
# there is data with in Burnside of numberSold
# there is data with in Burnside of highestSoldPrice
# there is data with in Burnside of lowestSoldPrice
# there is data with in Burnside of 5thPercentileSoldPrice
# there is data with in Burnside of 25thPercentileSoldPrice
# there is data with in Burnside of 75thPercentileSoldPrice
# there is data with in Burnside of 95thPercentileSoldPrice
# there is data with in Burnside of medianSaleListingPrice
# there is data with in Burnside of numberSaleListing
# there is data with in Burnside of highestSaleListingPrice
# there is data with in Burnside of lowestSaleListingPrice
# there is data with in Burnside of auctionNumberAuctioned
# there is data with in Burnside of auctionNumberSold
# there is data with in Burnside of medianRentListingPrice
# there is data with in Burnside of numberRentListing
# there is data with in Burnside of highestRentListingPrice
# there is data with in Burnside of lowestRentListingPrice
# 3023
# there is data with in Burnside Heights of medianSoldPrice
# there is data with in Burnside Heights of numberSold
# there is data with in Burnside Heights of highestSoldPrice
# there is data with in Burnside Heights of lowestSoldPrice
# there is data with in Burnside Heights of 5thPercentileSoldPrice
# there is data with in Burnside Heights of 25thPercentileSoldPrice
# there is data with in Burnside Heights of 75thPercentileSoldPrice
# there is data with in Burnside Heights of 95thPercentileSoldPrice
# there is data with in Burnside Heights of medianSaleListingPrice
# there is data with in Burnside Heights of numberSaleListing
# there is data with in Burnside Heights of highestSaleListingPrice
# there is data with in Burnside Heights of lowestSaleListingPrice
# there is data with in Burnside Heights of auctionNumberAuctioned
# there is data with in Burnside Heights of auctionNumberSold
# there is data with in Burnside Heights of medianRentListingPrice
# there is data with in Burnside Heights of numberRentListing
# there is data with in Burnside Heights of highestRentListingPrice
# there is data with in Burnside Heights of lowestRentListingPrice
# 3125
# there is data with in Burwood of medianSoldPrice
# there is data with in Burwood of numberSold
# there is data with in Burwood of highestSoldPrice
# there is data with in Burwood of lowestSoldPrice
# there is data with in Burwood of 5thPercentileSoldPrice
# there is data with in Burwood of 25thPercentileSoldPrice
# there is data with in Burwood of 75thPercentileSoldPrice
# there is data with in Burwood of 95thPercentileSoldPrice
# there is data with in Burwood of medianSaleListingPrice
# there is data with in Burwood of numberSaleListing
# there is data with in Burwood of highestSaleListingPrice
# there is data with in Burwood of lowestSaleListingPrice
# there is data with in Burwood of auctionNumberAuctioned
# there is data with in Burwood of auctionNumberSold
# there is data with in Burwood of medianRentListingPrice
# there is data with in Burwood of numberRentListing
# there is data with in Burwood of highestRentListingPrice
# there is data with in Burwood of lowestRentListingPrice
# 3151
# there is data with in Burwood East of medianSoldPrice
# there is data with in Burwood East of numberSold
# there is data with in Burwood East of highestSoldPrice
# there is data with in Burwood East of lowestSoldPrice
# there is data with in Burwood East of 5thPercentileSoldPrice
# there is data with in Burwood East of 25thPercentileSoldPrice
# there is data with in Burwood East of 75thPercentileSoldPrice
# there is data with in Burwood East of 95thPercentileSoldPrice
# there is data with in Burwood East of medianSaleListingPrice
# there is data with in Burwood East of numberSaleListing
# there is data with in Burwood East of highestSaleListingPrice
# there is data with in Burwood East of lowestSaleListingPrice
# there is data with in Burwood East of auctionNumberAuctioned
# there is data with in Burwood East of auctionNumberSold
# there is data with in Burwood East of medianRentListingPrice
# there is data with in Burwood East of numberRentListing
# there is data with in Burwood East of highestRentListingPrice
# there is data with in Burwood East of lowestRentListingPrice
# 3023
# there is data with in Cairnlea of medianSoldPrice
# there is data with in Cairnlea of numberSold
# there is data with in Cairnlea of highestSoldPrice
# there is data with in Cairnlea of lowestSoldPrice
# there is data with in Cairnlea of 5thPercentileSoldPrice
# there is data with in Cairnlea of 25thPercentileSoldPrice
# there is data with in Cairnlea of 75thPercentileSoldPrice
# there is data with in Cairnlea of 95thPercentileSoldPrice
# there is data with in Cairnlea of medianSaleListingPrice
# there is data with in Cairnlea of numberSaleListing
# there is data with in Cairnlea of highestSaleListingPrice
# there is data with in Cairnlea of lowestSaleListingPrice
# there is data with in Cairnlea of auctionNumberAuctioned
# there is data with in Cairnlea of auctionNumberSold
# there is data with in Cairnlea of medianRentListingPrice
# there is data with in Cairnlea of numberRentListing
# there is data with in Cairnlea of highestRentListingPrice
# there is data with in Cairnlea of lowestRentListingPrice
# 3037
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-47-551aec7131b4> in <module>
#      22              "totalPeriods":3}
#      23     res = requests.get(url_sale, headers=auth, params = params)
# ---> 24     s = res.json()
#      25     i = i + 1
#      26     #s["series"]["seriesInfo"][0]["values"] represent 2019
#
# ~/opt/anaconda3/envs/PythonDate/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/envs/PythonDate/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/opt/anaconda3/envs/PythonDate/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/opt/anaconda3/envs/PythonDate/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
yearly_data_2019.head()
# Out:
#                 Suburb  ID_Domain
# Postcode
# 3067        Abbotsford        627
# 3040        Aberfeldie        647
# 3042      Airport West        757
# 3021         Albanvale        787
# 3206       Albert Park        797

# %%
yearly_data_2020.head()
# Out:
#                 Suburb  ID_Domain  medianSoldPrice  numberSold  \
# Postcode
# 3067        Abbotsford        627        1150000.0        67.0
# 3040        Aberfeldie        647        1370000.0        43.0
# 3042      Airport West        757         793000.0       126.0
# 3021         Albanvale        787         515000.0        57.0
# 3206       Albert Park        797        2013000.0       112.0
#
#           highestSoldPrice  lowestSoldPrice  5thPercentileSoldPrice  \
# Postcode
# 3067             2150000.0         535000.0                860000.0
# 3040             3850000.0         756000.0                910000.0
# 3042             1240000.0         515000.0                581000.0
# 3021              670000.0         420000.0                430000.0
# 3206             9010000.0         646000.0                970000.0
#
#           25thPercentileSoldPrice  75thPercentileSoldPrice  \
# Postcode
# 3067                     960000.0                1355000.0
# 3040                    1110000.0                1705000.0
# 3042                     705000.0                 865000.0
# 3021                     480000.0                 538000.0
# 3206                    1425000.0                2820000.0
#
#           95thPercentileSoldPrice  medianSaleListingPrice  numberSaleListing  \
# Postcode
# 3067                    1900000.0               1100000.0               76.0
# 3040                    3000000.0               1485000.0               52.0
# 3042                    1045000.0                765000.0              158.0
# 3021                     600000.0                505000.0               76.0
# 3206                    5500000.0               2325000.0              110.0
#
#           highestSaleListingPrice  lowestSaleListingPrice  \
# Postcode
# 3067                    2700000.0                115000.0
# 3040                    6800000.0                840000.0
# 3042                    2280000.0                425000.0
# 3021                     850000.0                365000.0
# 3206                   12325000.0                365000.0
#
#           auctionNumberAuctioned  auctionNumberSold  medianRentListingPrice  \
# Postcode
# 3067                        55.0               38.0                   650.0
# 3040                        31.0               22.0                   578.0
# 3042                        84.0               50.0                   440.0
# 3021                        13.0                8.0                   350.0
# 3206                        79.0               48.0                   800.0
#
#           numberRentListing  highestRentListingPrice  lowestRentListingPrice
# Postcode
# 3067                  147.0                   1450.0                   350.0
# 3040                   66.0                   1400.0                   340.0
# 3042                  240.0                    825.0                   300.0
# 3021                   62.0                    520.0                   290.0
# 3206                  253.0                   2500.0                   350.0

# %%
yearly_data_2021.head()
# Out:
#                 Suburb  ID_Domain  medianSoldPrice  numberSold  \
# Postcode
# 3067        Abbotsford        627        1210000.0        69.0
# 3040        Aberfeldie        647        1638000.0        42.0
# 3042      Airport West        757         800000.0       144.0
# 3021         Albanvale        787         563000.0        63.0
# 3206       Albert Park        797        1953000.0        96.0
#
#           highestSoldPrice  lowestSoldPrice  5thPercentileSoldPrice  \
# Postcode
# 3067             2810000.0         735000.0                863000.0
# 3040             3550000.0         790000.0                922000.0
# 3042             2110000.0         427000.0                525000.0
# 3021             1895000.0         415000.0                462000.0
# 3206            10750000.0         690000.0               1139000.0
#
#           25thPercentileSoldPrice  75thPercentileSoldPrice  \
# Postcode
# 3067                    1025000.0                1405000.0
# 3040                    1365000.0                1945000.0
# 3042                     685000.0                 920000.0
# 3021                     510000.0                 607000.0
# 3206                    1660000.0                2535000.0
#
#           95thPercentileSoldPrice  medianSaleListingPrice  numberSaleListing  \
# Postcode
# 3067                    1886000.0               1178000.0               92.0
# 3040                    2685000.0               1500000.0               59.0
# 3042                    1090000.0                780000.0              182.0
# 3021                     800000.0                540000.0               98.0
# 3206                    4575000.0               2125000.0              130.0
#
#           highestSaleListingPrice  lowestSaleListingPrice  \
# Postcode
# 3067                    2625000.0                115000.0
# 3040                    4450000.0                700000.0
# 3042                    2100000.0                 60000.0
# 3021                     855000.0                365000.0
# 3206                   11000000.0                599000.0
#
#           auctionNumberAuctioned  auctionNumberSold  medianRentListingPrice  \
# Postcode
# 3067                        45.0               29.0                   600.0
# 3040                        26.0               15.0                   630.0
# 3042                        79.0               49.0                   450.0
# 3021                         9.0                5.0                   350.0
# 3206                        69.0               43.0                   750.0
#
#           numberRentListing  highestRentListingPrice  lowestRentListingPrice
# Postcode
# 3067                  197.0                   1300.0                   320.0
# 3040                   65.0                   1950.0                   330.0
# 3042                  217.0                    825.0                   300.0
# 3021                   67.0                    520.0                   300.0
# 3206                  254.0                   2825.0                   295.0
